# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv ('covid_19_data.csv')
df.head(20)
# Out:
#     SNo ObservationDate  Province/State  Country/Region      Last Update  \
# 0     1      01/22/2020           Anhui  Mainland China  1/22/2020 17:00
# 1     2      01/22/2020         Beijing  Mainland China  1/22/2020 17:00
# 2     3      01/22/2020       Chongqing  Mainland China  1/22/2020 17:00
# 3     4      01/22/2020          Fujian  Mainland China  1/22/2020 17:00
# 4     5      01/22/2020           Gansu  Mainland China  1/22/2020 17:00
# 5     6      01/22/2020       Guangdong  Mainland China  1/22/2020 17:00
# 6     7      01/22/2020         Guangxi  Mainland China  1/22/2020 17:00
# 7     8      01/22/2020         Guizhou  Mainland China  1/22/2020 17:00
# 8     9      01/22/2020          Hainan  Mainland China  1/22/2020 17:00
# 9    10      01/22/2020           Hebei  Mainland China  1/22/2020 17:00
# 10   11      01/22/2020    Heilongjiang  Mainland China  1/22/2020 17:00
# 11   12      01/22/2020           Henan  Mainland China  1/22/2020 17:00
# ...

# %%
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  285307.000000  2.853070e+05  285307.000000  2.853070e+05
# mean   142654.000000  7.662923e+04    1867.334661  4.478423e+04
# std     82361.180963  2.466176e+05    5905.565551  1.788030e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     71327.500000  9.700000e+02      12.000000  1.100000e+01
# 50%    142654.000000  9.181000e+03     172.000000  1.552000e+03
# 75%    213980.500000  4.561800e+04    1181.000000  1.793500e+04
# max    285307.000000  5.605532e+06  112182.000000  6.399531e+06

# %%
df.corr()
# Out:
#                 SNo  Confirmed    Deaths  Recovered
# SNo        1.000000   0.238245  0.191927   0.187631
# Confirmed  0.238245   1.000000  0.885990   0.591882
# Deaths     0.191927   0.885990  1.000000   0.509682
# Recovered  0.187631   0.591882  0.509682   1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # We can clearly see that 'Guangdong' state in china has the highest conformed cases as compared to other states

# %%
import pandas as pd
from matplotlib import pyplot as plt

 
states = df['Province/State']
Confirmed_cases = df['Confirmed']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(states[0:10], Confirmed_cases[0:10])
 
# Show Plot
plt.show()
